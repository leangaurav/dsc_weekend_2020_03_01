# %% [markdown]
# # Assignment 6

# %%
#1.WAP to print first n natural numbers (input n from user). 

n=int(input("enter the value of n:"))
for i in range(1,n+1):
    print(i)
# Out:
# enter the value of n:7
# 1
# 2
# 3
# 4
# 5
# 6
# 7

# %%
 2#.WAP to find sum of first n natural numbers 
n=int(input("enter the value of n:"))
su=0
for i in range(1,n+1):
    su=su+i
print(su)
# Out:
# enter the value of n:6
# 21

# %%
#3.WAP to print first n natural numbers in reverse order.
n=int(input("enter the value of n:"))
for i in range(n, 0, -1):
    print(i)
# Out:
# enter the value of n:8
# 8
# 7
# 6
# 5
# 4
# 3
# 2
# 1

# %%
#4.WAP to input a number and print its factorial.
n=int(input("enter the value of n:"))
fa=1 #should not initialize to 0
for i in range(1,n+1):
    fa=fa*i
print(fa)


#using while loop
n=int(input("Enter number:"))
fact=1
while(n>0):
    fact=fact*n
    n=n-1
print("Factorial of the number is: ")
print(fact)
# Out:
# enter the value of n:3
# 6
# Enter number:4
# Factorial of the number is:
# 24

# %%
#5.WAP to print Fibonacci sequence till n.(Fibonacci series is a series in which each number is the sum of the preceding two numbers)
n = int(input("Enter the value of n: "))
a = 0
b = 1
sum = 0
count = 1
while(count <= n):
    print(sum, end = " ")
    count += 1
    a = b
    b = sum
    sum = a + b
# Out:
# Enter the value of n: 5
# 0 1 1 2 3

# %%
#6.WAP to print all digits of a number input from user.

# %%
#7.WAP to find sum of all digits of a number. 

n=int(input("enter the input:"))
result=0
while n >0:
    digit= n%10
    result = result+digit
    n=n//10
print(result)



n=int(input("enter the input:"))
result=0
for i in range(len(str(n))):
    digit= n%10
    result = result+digit
    n=n//10
print(result)
# Out:
# enter the input:123
# 6
# enter the input:123
# 6

# %%
#8.WAP to find sum of following series given n as input from user.1 + 2! + 3! + 4! + 5! + ….n! Where n! denotes the factorial of number n.

N = int(input("Enter the Value of N:"))
S=0

for i in range(1, N+1):
    fact=1
    
    for j in range(1, i+1):
        fact=fact*j
    
    S=S+fact
    
    print(str(i)+"!",end="")
    if i!=N:
        print("+",end="")
print("=" + str(S))
# Out:
# Enter the Value of N:5
# 1!+2!+3!+4!+5!=153

# %%
#9.WAP to input base and exponent and print result without using inbuilt function pow(use for or while loop). 


base = int(input("Enter the base: "))
expo = int(input("Enter the exponent: "))

k = 1
for n in range(expo):
    k = k*base

print(k)
# Out:
# Enter the base: 3
# Enter the exponent: 2
# 9

# %% [markdown]
# 10.Print following patterns:
# ![image.png](attachment:image.png)

# %%
n=int(input("enter the number")) #how many rows we need, here we need 5 rows
for i in range(1,n+1):
    for j in range(1,i+1):
        print("*",end=" ")
    print()#goes to next line
# Out:
# enter the number5
# *
# * *
# * * *
# * * * *
# * * * * *

# %% [markdown]
# 10.b.Print following patterns
# ![image.png](attachment:image.png)

# %%
n=int(input("enter the number:")) #how many rows we need, here we need 5 rows
for i in range(n,0,-1):
    for j in range(0,i):
        print("*",end=" ")
    print()#goes to next line
# Out:
# enter the number:5
# * * * * *
# * * * *
# * * *
# * *
# *

# %% [markdown]
# 10.c.Print following patterns
# mirrored right angle triangle
# ![image.png](attachment:image.png)

# %%
n=int(input("Enter the number of rows: "))
 
for i in range(1,n+1):
    
    for j in range(i,n):
        print(end=" ")
 
    for j in range(1,i+1):
        print("*",end="")
    print()
# Out:
# Enter the number of rows: 5
#     *
#    **
#   ***
#  ****
# *****

# %% [markdown]
# ### 10.d.Print following patterns
# ![image.png](attachment:image.png)

# %%
num=int(input("enter the number"))
for i in range(0,num):
    for j in range(0,num-i-1):
        print(end=" ")
    for j in range(0,i+1):
        print("*",end=" ")
    print()
# Out:
# enter the number4
#    *
#   * *
#  * * *
# * * * *

# %% [markdown]
# 11.a. Print following number patterns
#
# ![image.png](attachment:image.png)

# %%
n=int(input("enter the number of rows:"))
for i in range(1,n+1):
    for j in range(1,i+1):
        print(i,end="")
    print()
# Out:
# enter the number of rows:5
# 1
# 22
# 333
# 4444
# 55555

# %% [markdown]
# 11.b. Print following number patterns
# ![image.png](attachment:image.png)

# %%
n=int(input("enter the number of rows:"))
for i in range(1,n+1):
    for j in range(1,i+1):
        print(j,end="")
    print()
# Out:
# enter the number of rows:5
# 1
# 12
# 123
# 1234
# 12345

# %% [markdown]
# 11.c. Print following number patterns
# ![image.png](attachment:image.png)

# %%
n=int(input("enter the number of rows"))
for i in range(n,0,-1):
    for j in range(n,i-1,-1):
        print(i,end=" ")
    print()
# Out:
# enter the number of rows5
# 5
# 4 4
# 3 3 3
# 2 2 2 2
# 1 1 1 1 1

# %% [markdown]
# 11.d. Print following number patterns
# ![image.png](attachment:image.png)

# %%
n=int(input("Enter the number of rows: "))
 
for i in range(1,n+1):
    
    for j in range(i,n):
        print(end=" ")
 
    for j in range(1,i+1):
        print(i,end="")
    print()
# Out:
# Enter the number of rows: 5
#     1
#    22
#   333
#  4444
# 55555

# %% [markdown]
# 13.a.Print following character patterns:
# ![image.png](attachment:image.png)

# %%
n=int(input("enter the number of rows:"))

for i in range(1,n+1):
    x=65
    for j in range(1,i+1):
        
        print(chr(x),end="")
        x+=1
    print()
# Out:
# enter the number of rows:5
# A
# AB
# ABC
# ABCD
# ABCDE

# %% [markdown]
# 13.b.Print following character patterns:
# ![image.png](attachment:image.png)

# %%
n=int(input("enter the number of rows:"))
ascci=65
for i in range(0,n):
    for j in range(0,i+1):
        val =chr(ascci)
        print(val,end="")
        ascci+=1
    print()
# Out:
# enter the number of rows:5
# A
# BC
# DEF
# GHIJ
# KLMNO

# %% [markdown]
# 13.c.Print following character patterns:
# ![image.png](attachment:image.png)

# %%
n=int(input("enter the number of rows:"))
for i in range(n):
    print((chr(65+i)+' ')*(i+1))
# Out:
# enter the number of rows:5
# A
# B B
# C C C
# D D D D
# E E E E E

# %% [markdown]
# 13.d.Print following character patterns:
# ![image.png](attachment:image.png)

# %%
n=int(input("enter the number of rows:"))
for i in range(n):
    for j in range(n-i):
        print(end=' ')
    for j in range(i+1):
        print(chr(65+j),end='')
    for j in range(i,0,-1):
        print(chr(64+j), end='')
    print()
# Out:
# enter the number of rows:5
#      A
#     ABA
#    ABCBA
#   ABCDCBA
#  ABCDEDCBA
